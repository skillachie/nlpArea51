# %%
from sklearn.svm import LinearSVC
from gensim.models import Word2Vec
from sklearn import metrics
from sklearn.naive_bayes import MultinomialNB
from sklearn import svm
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
#from abstract import *
from sklearn.datasets import fetch_20newsgroups
from nltk.corpus import stopwords
import numpy as np
from sklearn.cross_validation import cross_val_score, KFold
from sklearn.metrics import classification_report

# %%
categories = ['alt.atheism', 'talk.religion.misc','comp.graphics', 'sci.space']
newsgroups_train = fetch_20newsgroups(subset='train',categories=categories, remove=('headers', 'footers', 'quotes'))
newsgroups_test = fetch_20newsgroups(subset='test',categories=categories, remove=('headers', 'footers', 'quotes'))

# %%
from pprint import pprint
#pprint(newsgroups_train)

# %% [markdown]
# # Using TF-IDF

# %%
vectorizer = TfidfVectorizer()
le = LabelEncoder()

# Training 
vectors_train = vectorizer.fit_transform(newsgroups_train.data)
labels_train = le.fit_transform(newsgroups_train.target)

# Just for debug quickly reassign labels
X = vectors_train
y = labels_train


clf = MultinomialNB(alpha=.01)
#clf = svm.SVC(kernel='linear', C = 1.0)

# Evaluate using cross validation
cross_val = KFold(len(newsgroups_train.target),n_folds=5,shuffle=True)

#for train_index, test_index in cross_val:
#    X_train,X_test = X[train_index],X[test_index]
#    y_train,y_test = y[train_index],y[test_index]
#    clf.fit(X_train,y_train)
#    y_pred = clf.predict(X_test)
#    print classification_report(le.inverse_transform(y_test),le.inverse_transform(y_pred))
#    print metrics.confusion_matrix(y_pred,y_test)


clf.fit(vectors_train, newsgroups_train.target)
vectors_test = vectorizer.transform(newsgroups_test.data)
pred = clf.predict(vectors_test)

#print metrics.f1_score(newsgroups_test.target, pred)
print classification_report(le.inverse_transform(newsgroups_test.target),le.inverse_transform(pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.68      0.68      0.68       319
#           1       0.92      0.89      0.91       389
#           2       0.81      0.90      0.85       394
#           3       0.68      0.60      0.64       251
#
# avg / total       0.79      0.79      0.79      1353

# %% [markdown]
# # Using Word2Vec

# %%
from gensim.models import Doc2Vec
import gensim.models.doc2vec
from collections import OrderedDict
import multiprocessing
from gensim.models.doc2vec import TaggedDocument
import sys

cores = multiprocessing.cpu_count()
assert gensim.models.doc2vec.FAST_VERSION > -1, "this will be painfully slow otherwise"

# %%
from collections import namedtuple
import nltk

NewsgroupDocument = namedtuple('NewsGroupDocument', 'words tags split category')
doc_count = 0 # Used to generate unique id for all documents across both train and test

all_newsgroup_documents = []

#Used to convert newsgroup corpus into Doc2Vec formats
def convert_newsgroup(docs,labels,split):
    global doc_count
    tagged_documents = []
    
    for doc, label in zip(docs,labels):
        doc_count += 1
        #print doc
        words = gensim.utils.to_unicode(doc).split() # expected by gensim
        tags = [doc_count] #needs to be a list. Exp with having multiple tags
        all_newsgroup_documents.append(NewsgroupDocument(words,tags,split,label))
        #print words
        
        #if doc_count == 5:
        #    print all_newsgroup_documents
        #    break
            #sys.exit(0)
    

convert_newsgroup(newsgroups_test.data,newsgroups_test.target,'test')
convert_newsgroup(newsgroups_train.data,newsgroups_train.target,'train')

train_docs = [doc for doc in all_newsgroup_documents if doc.split == 'train']
test_docs = [doc for doc in all_newsgroup_documents if doc.split == 'test']
doc_list = all_newsgroup_documents[:]  # for reshuffling per pass

print('%d docs: %d train, %d test' % (len(doc_list), len(train_docs), len(test_docs)))
# Out:
# 3387 docs: 2034 train, 1353 test

# %% [markdown]
# ### Set Up Word2Vec

# %%
# Models to evaluate
simple_models = [
    # PV-DM w/concatenation - window=5 (both sides) approximates paper's 10-word total window size
    #Doc2Vec(dm=1, dm_concat=1, size=100, window=5, negative=5, hs=0, min_count=2, workers=cores),
    # PV-DBOW 
    Doc2Vec(dm=0, size=100, negative=5, hs=0, min_count=2, workers=cores),
    # PV-DM w/average
    #Doc2Vec(dm=1, dm_mean=1, size=300, window=10, negative=5, hs=0, min_count=2, workers=cores),
]

# speed setup by sharing results of 1st model's vocabulary scan
simple_models[0].build_vocab(all_newsgroup_documents)  # PV-DM/concat requires one special NULL word so it serves as template
print(simple_models[0])
for model in simple_models[1:]:
    model.reset_from(simple_models[0])
    print(model)

models_by_name = OrderedDict((str(model), model) for model in simple_models)
# Out:
# Doc2Vec(dbow,d100,n5,mc2,t8)

# %% [markdown]
# ### Prediction and Evaluation

# %%
import numpy as np
import statsmodels.api as sm
from random import sample

# for timing
from contextlib import contextmanager
from timeit import default_timer
import time 

@contextmanager
def elapsed_timer():
    start = default_timer()
    elapser = lambda: default_timer() - start
    yield lambda: elapser()
    end = default_timer()
    elapser = lambda: end-start
    
def logistic_predictor_from_data(train_targets, train_regressors):
    logit = sm.Logit(train_targets, train_regressors)
    predictor = logit.fit(disp=0)
    #print(predictor.summary())
    return predictor

def error_rate_for_model(test_model, train_set, test_set, infer=False, infer_steps=3, infer_alpha=0.1, infer_subsample=0.1):
    """Report error rate on test_doc sentiments, using supplied model and train_docs"""

    train_targets, train_regressors = zip(*[(doc.category, test_model.docvecs[doc.tags[0]]) for doc in train_set])
    #print train_regressors
    #train_regressors = sm.add_constant(train_regressors)
    predictor = logistic_predictor_from_data(train_targets, train_regressors)

    test_data = test_set
    if infer:
        if infer_subsample < 1.0:
            test_data = sample(test_data, int(infer_subsample * len(test_data)))
        test_regressors = [test_model.infer_vector(doc.words, steps=infer_steps, alpha=infer_alpha) for doc in test_data]
    else:
        test_regressors = [test_model.docvecs[doc.tags[0]] for doc in test_docs]
    test_regressors = sm.add_constant(test_regressors)
    
    # predict & evaluate
    test_predictions = predictor.predict(test_regressors)
    corrects = sum(np.rint(test_predictions) == [doc.category for doc in test_data])
    errors = len(test_predictions) - corrects
    error_rate = float(errors) / len(test_predictions)
    return (error_rate, errors, len(test_predictions), predictor)

# %% [markdown]
# ### Training

# %% [markdown]
# Why is bulk training done with all the  docs from train, test,  and dev ? Compared to other methods training is only done on the training dataset

# %%
from collections import defaultdict
best_error = defaultdict(lambda :1.0)  # to selectively-print only best errors achieved

# %%
#Get Vectors From Word2Vec
def extract_vectors(model,docs):
    
    vectors_list = []
    
    for doc_no in range(len(docs)):
        doc_label = docs[doc_no].tags[0]
        doc_vector = model.docvecs[doc_label]
        vectors_list.append(doc_vector)
        
    return vectors_list

def evaluation():
    clf = MultinomialNB(alpha=.01)

    # Evaluate using cross validation
    cross_val = KFold(len(newsgroups_train.target),n_folds=5,shuffle=True)

    for train_index, test_index in cross_val:
        X_train,X_test = X[train_index],X[test_index]
        y_train,y_test = y[train_index],y[test_index]
        clf.fit(X_train,y_train)
        y_pred = clf.predict(X_test)
        print classification_report(le.inverse_transform(y_test),le.inverse_transform(y_pred))
        print metrics.confusion_matrix(y_pred,y_test)

# %%
from random import shuffle
alpha, min_alpha, passes = (0.025, 0.001, 250)
alpha_delta = (alpha - min_alpha) / passes

for epoch in range(passes):
    shuffle(doc_list)
    
    for name, train_model in models_by_name.items():
        
        #Train
        #train_model.alpha, train_model.min_alpha = alpha, alpha
        train_model.alpha -= 0.002  # decrease the learning rate
        train_model.min_alpha = model.alpha  # fix the learning rate, no decay
        train_model.train(doc_list)
            
        #Evaluation
        train_vectors = extract_vectors(train_model,train_docs)
        test_vectors = extract_vectors(train_model,test_docs)
      
        #clf = MultinomialNB(alpha=.01)
        clf = svm.SVC(kernel='linear', C = 1.0)
        clf.fit(train_vectors, newsgroups_train.target)
        pred = clf.predict(test_vectors)
        
        print classification_report(le.inverse_transform(newsgroups_test.target),le.inverse_transform(pred))
        print("%i passes : %s " % (epoch + 1, name))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.45      0.19      0.27       319
#           1       0.36      0.85      0.50       389
#           2       0.46      0.33      0.38       394
#           3       0.75      0.04      0.07       251
#
# avg / total       0.48      0.39      0.33      1353
#
# 1 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.52      0.48      0.50       319
#           1       0.53      0.88      0.66       389
#           2       0.58      0.53      0.56       394
#           3       0.62      0.10      0.17       251
#
# avg / total       0.56      0.54      0.50      1353
#
# 2 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.50      0.58      0.54       319
#           1       0.61      0.89      0.72       389
#           2       0.65      0.61      0.63       394
#           3       0.56      0.11      0.19       251
#
# avg / total       0.59      0.59      0.55      1353
#
# 3 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.51      0.63      0.56       319
#           1       0.67      0.88      0.76       389
#           2       0.69      0.67      0.68       394
#           3       0.57      0.13      0.21       251
#
# avg / total       0.62      0.62      0.59      1353
#
# 4 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.52      0.63      0.57       319
#           1       0.69      0.88      0.78       389
#           2       0.70      0.71      0.70       394
#           3       0.58      0.17      0.26       251
#
# avg / total       0.63      0.64      0.61      1353
#
# 5 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.51      0.66      0.57       319
#           1       0.72      0.88      0.79       389
#           2       0.73      0.70      0.71       394
#           3       0.56      0.20      0.29       251
#
# avg / total       0.64      0.65      0.62      1353
#
# 6 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.52      0.67      0.59       319
#           1       0.73      0.88      0.80       389
#           2       0.75      0.72      0.73       394
#           3       0.58      0.21      0.31       251
#
# avg / total       0.66      0.66      0.64      1353
#
# 7 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.53      0.67      0.59       319
#           1       0.73      0.88      0.80       389
#           2       0.75      0.71      0.73       394
#           3       0.59      0.25      0.35       251
#
# avg / total       0.66      0.66      0.65      1353
#
# 8 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.52      0.66      0.58       319
#           1       0.78      0.87      0.82       389
#           2       0.76      0.71      0.73       394
#           3       0.49      0.29      0.37       251
#
# avg / total       0.66      0.67      0.66      1353
#
# 9 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.52      0.65      0.58       319
#           1       0.80      0.86      0.83       389
#           2       0.76      0.72      0.74       394
#           3       0.48      0.31      0.37       251
#
# avg / total       0.66      0.67      0.66      1353
#
# 10 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.53      0.66      0.59       319
#           1       0.80      0.86      0.83       389
#           2       0.76      0.72      0.74       394
#           3       0.48      0.31      0.38       251
#
# avg / total       0.66      0.67      0.66      1353
#
# 11 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.53      0.66      0.59       319
#           1       0.80      0.86      0.83       389
#           2       0.76      0.72      0.74       394
#           3       0.48      0.31      0.38       251
#
# avg / total       0.67      0.67      0.66      1353
#
# 12 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.53      0.66      0.59       319
#           1       0.80      0.86      0.83       389
#           2       0.76      0.72      0.74       394
#           3       0.48      0.31      0.38       251
#
# avg / total       0.66      0.67      0.66      1353
#
# 13 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.51      0.69      0.58       319
#           1       0.80      0.85      0.83       389
#           2       0.75      0.72      0.74       394
#           3       0.52      0.26      0.35       251
#
# avg / total       0.66      0.67      0.65      1353
#
# 14 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.50      0.71      0.58       319
#           1       0.80      0.85      0.82       389
#           2       0.73      0.72      0.73       394
#           3       0.61      0.25      0.35       251
#
# avg / total       0.67      0.67      0.65      1353
#
# 15 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.52      0.65      0.58       319
#           1       0.75      0.86      0.80       389
#           2       0.70      0.73      0.72       394
#           3       0.59      0.24      0.34       251
#
# avg / total       0.65      0.66      0.64      1353
#
# 16 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.53      0.66      0.59       319
#           1       0.74      0.86      0.80       389
#           2       0.70      0.73      0.72       394
#           3       0.61      0.24      0.34       251
#
# avg / total       0.66      0.66      0.64      1353
#
# 17 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.53      0.65      0.58       319
#           1       0.74      0.86      0.80       389
#           2       0.70      0.73      0.72       394
#           3       0.60      0.23      0.33       251
#
# avg / total       0.65      0.66      0.64      1353
#
# 18 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.52      0.63      0.57       319
#           1       0.73      0.85      0.78       389
#           2       0.68      0.72      0.70       394
#           3       0.59      0.22      0.31       251
#
# avg / total       0.64      0.64      0.62      1353
#
# 19 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.52      0.61      0.56       319
#           1       0.72      0.85      0.78       389
#           2       0.68      0.72      0.70       394
#           3       0.57      0.21      0.30       251
#
# avg / total       0.63      0.64      0.62      1353
#
# 20 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.52      0.60      0.56       319
#           1       0.72      0.85      0.78       389
#           2       0.67      0.73      0.70       394
#           3       0.56      0.21      0.31       251
#
# avg / total       0.63      0.64      0.62      1353
#
# 21 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.52      0.60      0.56       319
#           1       0.70      0.84      0.76       389
#           2       0.65      0.71      0.68       394
#           3       0.58      0.21      0.31       251
#
# avg / total       0.62      0.63      0.61      1353
#
# 22 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.52      0.58      0.55       319
#           1       0.69      0.81      0.74       389
#           2       0.63      0.71      0.66       394
#           3       0.58      0.21      0.31       251
#
# avg / total       0.61      0.61      0.59      1353
#
# 23 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.50      0.56      0.53       319
#           1       0.67      0.79      0.72       389
#           2       0.62      0.70      0.65       394
#           3       0.55      0.20      0.30       251
#
# avg / total       0.59      0.60      0.58      1353
#
# 24 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.50      0.55      0.52       319
#           1       0.67      0.79      0.72       389
#           2       0.60      0.69      0.64       394
#           3       0.54      0.20      0.29       251
#
# avg / total       0.59      0.59      0.57      1353
#
# 25 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.46      0.58      0.51       319
#           1       0.71      0.76      0.74       389
#           2       0.61      0.68      0.64       394
#           3       0.52      0.20      0.29       251
#
# avg / total       0.59      0.59      0.57      1353
#
# 26 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.45      0.56      0.50       319
#           1       0.72      0.77      0.74       389
#           2       0.61      0.68      0.64       394
#           3       0.51      0.20      0.29       251
#
# avg / total       0.58      0.59      0.57      1353
#
# 27 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.46      0.56      0.51       319
#           1       0.72      0.76      0.74       389
#           2       0.60      0.69      0.64       394
#           3       0.51      0.21      0.30       251
#
# avg / total       0.58      0.59      0.57      1353
#
# 28 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.45      0.56      0.50       319
#           1       0.71      0.74      0.73       389
#           2       0.58      0.68      0.63       394
#           3       0.52      0.20      0.29       251
#
# avg / total       0.58      0.58      0.56      1353
#
# 29 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.45      0.58      0.50       319
#           1       0.72      0.73      0.72       389
#           2       0.59      0.68      0.63       394
#           3       0.54      0.20      0.30       251
#
# avg / total       0.58      0.58      0.56      1353
#
# 30 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.44      0.58      0.50       319
#           1       0.71      0.75      0.73       389
#           2       0.61      0.67      0.64       394
#           3       0.52      0.19      0.28       251
#
# avg / total       0.58      0.58      0.57      1353
#
# 31 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.48      0.55      0.51       319
#           1       0.66      0.76      0.71       389
#           2       0.59      0.67      0.63       394
#           3       0.55      0.20      0.29       251
#
# avg / total       0.58      0.58      0.56      1353
#
# 32 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.47      0.54      0.51       319
#           1       0.65      0.75      0.70       389
#           2       0.59      0.67      0.63       394
#           3       0.53      0.20      0.29       251
#
# avg / total       0.57      0.58      0.56      1353
#
# 33 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.49      0.55      0.52       319
#           1       0.63      0.74      0.68       389
#           2       0.58      0.66      0.62       394
#           3       0.52      0.19      0.28       251
#
# avg / total       0.56      0.57      0.55      1353
#
# 34 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.49      0.55      0.52       319
#           1       0.63      0.74      0.68       389
#           2       0.60      0.68      0.64       394
#           3       0.53      0.20      0.29       251
#
# avg / total       0.57      0.58      0.56      1353
#
# 35 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.45      0.57      0.51       319
#           1       0.67      0.72      0.69       389
#           2       0.61      0.68      0.64       394
#           3       0.49      0.18      0.26       251
#
# avg / total       0.57      0.57      0.55      1353
#
# 36 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.44      0.56      0.49       319
#           1       0.66      0.73      0.69       389
#           2       0.61      0.66      0.64       394
#           3       0.47      0.17      0.25       251
#
# avg / total       0.56      0.57      0.55      1353
#
# 37 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.43      0.57      0.49       319
#           1       0.65      0.72      0.68       389
#           2       0.62      0.64      0.63       394
#           3       0.50      0.18      0.26       251
#
# avg / total       0.56      0.56      0.55      1353
#
# 38 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.43      0.57      0.49       319
#           1       0.65      0.72      0.69       389
#           2       0.62      0.64      0.63       394
#           3       0.48      0.17      0.25       251
#
# avg / total       0.56      0.56      0.54      1353
#
# 39 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.43      0.56      0.49       319
#           1       0.64      0.72      0.68       389
#           2       0.62      0.64      0.63       394
#           3       0.47      0.17      0.25       251
#
# avg / total       0.55      0.56      0.54      1353
#
# 40 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.43      0.55      0.48       319
#           1       0.64      0.72      0.68       389
#           2       0.62      0.65      0.64       394
#           3       0.47      0.18      0.26       251
#
# avg / total       0.55      0.56      0.54      1353
#
# 41 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.43      0.55      0.48       319
#           1       0.62      0.70      0.65       389
#           2       0.62      0.63      0.62       394
#           3       0.47      0.18      0.26       251
#
# avg / total       0.55      0.55      0.53      1353
#
# 42 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.43      0.57      0.49       319
#           1       0.62      0.70      0.66       389
#           2       0.62      0.63      0.63       394
#           3       0.45      0.18      0.25       251
#
# avg / total       0.55      0.55      0.53      1353
#
# 43 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.42      0.56      0.48       319
#           1       0.62      0.69      0.65       389
#           2       0.62      0.62      0.62       394
#           3       0.46      0.18      0.25       251
#
# avg / total       0.54      0.54      0.53      1353
#
# 44 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.43      0.59      0.50       319
#           1       0.62      0.67      0.65       389
#           2       0.60      0.64      0.62       394
#           3       0.46      0.15      0.23       251
#
# avg / total       0.54      0.55      0.53      1353
#
# 45 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.43      0.58      0.50       319
#           1       0.61      0.69      0.65       389
#           2       0.61      0.62      0.62       394
#           3       0.46      0.15      0.22       251
#
# avg / total       0.54      0.54      0.52      1353
#
# 46 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.43      0.58      0.49       319
#           1       0.59      0.68      0.64       389
#           2       0.61      0.61      0.61       394
#           3       0.49      0.15      0.23       251
#
# avg / total       0.54      0.54      0.52      1353
#
# 47 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.43      0.57      0.49       319
#           1       0.58      0.68      0.63       389
#           2       0.61      0.61      0.61       394
#           3       0.47      0.14      0.22       251
#
# avg / total       0.53      0.54      0.51      1353
#
# 48 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.42      0.57      0.48       319
#           1       0.59      0.68      0.63       389
#           2       0.61      0.61      0.61       394
#           3       0.47      0.14      0.22       251
#
# avg / total       0.53      0.53      0.51      1353
#
# 49 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.44      0.57      0.50       319
#           1       0.56      0.69      0.62       389
#           2       0.60      0.59      0.60       394
#           3       0.50      0.15      0.23       251
#
# avg / total       0.53      0.53      0.51      1353
#
# 50 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.43      0.55      0.48       319
#           1       0.57      0.68      0.62       389
#           2       0.59      0.59      0.59       394
#           3       0.47      0.15      0.23       251
#
# avg / total       0.52      0.53      0.51      1353
#
# 51 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.42      0.54      0.48       319
#           1       0.56      0.68      0.61       389
#           2       0.60      0.59      0.59       394
#           3       0.43      0.14      0.22       251
#
# avg / total       0.52      0.52      0.50      1353
#
# 52 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.43      0.52      0.47       319
#           1       0.55      0.66      0.60       389
#           2       0.56      0.60      0.58       394
#           3       0.47      0.15      0.23       251
#
# avg / total       0.51      0.52      0.50      1353
#
# 53 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.44      0.49      0.46       319
#           1       0.53      0.66      0.59       389
#           2       0.55      0.60      0.57       394
#           3       0.45      0.15      0.22       251
#
# avg / total       0.50      0.51      0.49      1353
#
# 54 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.50      0.45       319
#           1       0.56      0.65      0.60       389
#           2       0.56      0.60      0.58       394
#           3       0.42      0.14      0.21       251
#
# avg / total       0.50      0.50      0.49      1353
#
# 55 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.50      0.45       319
#           1       0.55      0.64      0.59       389
#           2       0.54      0.59      0.56       394
#           3       0.42      0.14      0.21       251
#
# avg / total       0.49      0.50      0.48      1353
#
# 56 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.51      0.45       319
#           1       0.56      0.64      0.60       389
#           2       0.55      0.58      0.56       394
#           3       0.40      0.13      0.20       251
#
# avg / total       0.49      0.50      0.48      1353
#
# 57 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.42      0.49      0.45       319
#           1       0.53      0.63      0.58       389
#           2       0.53      0.58      0.55       394
#           3       0.44      0.16      0.23       251
#
# avg / total       0.49      0.49      0.48      1353
#
# 58 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.43      0.48      0.45       319
#           1       0.54      0.64      0.58       389
#           2       0.53      0.59      0.56       394
#           3       0.44      0.16      0.24       251
#
# avg / total       0.49      0.50      0.48      1353
#
# 59 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.48      0.44       319
#           1       0.54      0.63      0.58       389
#           2       0.52      0.59      0.55       394
#           3       0.42      0.16      0.23       251
#
# avg / total       0.48      0.49      0.48      1353
#
# 60 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.45      0.43       319
#           1       0.53      0.63      0.58       389
#           2       0.51      0.59      0.55       394
#           3       0.42      0.15      0.22       251
#
# avg / total       0.48      0.49      0.47      1353
#
# 61 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.42      0.45      0.43       319
#           1       0.53      0.62      0.57       389
#           2       0.51      0.60      0.55       394
#           3       0.42      0.15      0.22       251
#
# avg / total       0.47      0.48      0.47      1353
#
# 62 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.42      0.45      0.43       319
#           1       0.53      0.62      0.57       389
#           2       0.51      0.61      0.55       394
#           3       0.43      0.16      0.23       251
#
# avg / total       0.48      0.49      0.47      1353
#
# 63 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.42      0.45      0.43       319
#           1       0.53      0.61      0.56       389
#           2       0.50      0.60      0.55       394
#           3       0.44      0.16      0.23       251
#
# avg / total       0.48      0.48      0.47      1353
#
# 64 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.42      0.45      0.43       319
#           1       0.52      0.59      0.56       389
#           2       0.49      0.60      0.54       394
#           3       0.44      0.15      0.22       251
#
# avg / total       0.47      0.48      0.46      1353
#
# 65 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.42      0.45      0.43       319
#           1       0.53      0.58      0.55       389
#           2       0.48      0.60      0.54       394
#           3       0.44      0.16      0.23       251
#
# avg / total       0.47      0.48      0.46      1353
#
# 66 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.42      0.45      0.43       319
#           1       0.53      0.60      0.56       389
#           2       0.49      0.60      0.54       394
#           3       0.44      0.16      0.23       251
#
# avg / total       0.47      0.48      0.46      1353
#
# 67 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.46      0.43       319
#           1       0.53      0.57      0.55       389
#           2       0.49      0.59      0.53       394
#           3       0.42      0.15      0.22       251
#
# avg / total       0.46      0.47      0.45      1353
#
# 68 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.47      0.43       319
#           1       0.53      0.56      0.54       389
#           2       0.49      0.59      0.53       394
#           3       0.40      0.14      0.21       251
#
# avg / total       0.46      0.47      0.45      1353
#
# 69 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.45      0.43       319
#           1       0.53      0.56      0.54       389
#           2       0.48      0.61      0.53       394
#           3       0.42      0.15      0.22       251
#
# avg / total       0.46      0.47      0.45      1353
#
# 70 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.44      0.42       319
#           1       0.52      0.56      0.54       389
#           2       0.47      0.59      0.52       394
#           3       0.40      0.15      0.22       251
#
# avg / total       0.46      0.47      0.45      1353
#
# 71 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.42      0.45      0.43       319
#           1       0.52      0.55      0.53       389
#           2       0.47      0.61      0.53       394
#           3       0.40      0.16      0.23       251
#
# avg / total       0.46      0.47      0.45      1353
#
# 72 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.42      0.43      0.42       319
#           1       0.52      0.55      0.54       389
#           2       0.46      0.60      0.52       394
#           3       0.41      0.16      0.23       251
#
# avg / total       0.46      0.46      0.45      1353
#
# 73 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.42      0.44      0.43       319
#           1       0.51      0.55      0.53       389
#           2       0.45      0.59      0.51       394
#           3       0.40      0.15      0.22       251
#
# avg / total       0.45      0.46      0.44      1353
#
# 74 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.41      0.41       319
#           1       0.51      0.55      0.53       389
#           2       0.45      0.58      0.51       394
#           3       0.39      0.15      0.21       251
#
# avg / total       0.44      0.45      0.43      1353
#
# 75 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.41      0.41       319
#           1       0.52      0.55      0.53       389
#           2       0.46      0.60      0.52       394
#           3       0.37      0.15      0.21       251
#
# avg / total       0.45      0.46      0.44      1353
#
# 76 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.43      0.42       319
#           1       0.52      0.55      0.53       389
#           2       0.46      0.60      0.52       394
#           3       0.39      0.15      0.22       251
#
# avg / total       0.45      0.46      0.44      1353
#
# 77 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.43      0.42       319
#           1       0.52      0.55      0.54       389
#           2       0.45      0.59      0.51       394
#           3       0.37      0.15      0.21       251
#
# avg / total       0.45      0.46      0.44      1353
#
# 78 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.40      0.40       319
#           1       0.51      0.54      0.53       389
#           2       0.46      0.58      0.51       394
#           3       0.36      0.15      0.21       251
#
# avg / total       0.44      0.45      0.43      1353
#
# 79 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.40      0.41       319
#           1       0.51      0.54      0.52       389
#           2       0.45      0.59      0.51       394
#           3       0.37      0.15      0.21       251
#
# avg / total       0.44      0.45      0.43      1353
#
# 80 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.41      0.41       319
#           1       0.51      0.55      0.53       389
#           2       0.45      0.59      0.51       394
#           3       0.39      0.16      0.22       251
#
# avg / total       0.45      0.46      0.44      1353
#
# 81 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.40      0.40       319
#           1       0.52      0.56      0.54       389
#           2       0.46      0.60      0.52       394
#           3       0.37      0.15      0.22       251
#
# avg / total       0.45      0.46      0.44      1353
#
# 82 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.40      0.40       319
#           1       0.52      0.57      0.54       389
#           2       0.46      0.60      0.52       394
#           3       0.36      0.14      0.20       251
#
# avg / total       0.44      0.46      0.44      1353
#
# 83 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.40      0.40       319
#           1       0.52      0.57      0.54       389
#           2       0.46      0.60      0.52       394
#           3       0.33      0.14      0.19       251
#
# avg / total       0.44      0.46      0.44      1353
#
# 84 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.40      0.40       319
#           1       0.51      0.56      0.54       389
#           2       0.46      0.59      0.52       394
#           3       0.33      0.12      0.18       251
#
# avg / total       0.44      0.45      0.43      1353
#
# 85 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.42      0.41       319
#           1       0.52      0.58      0.55       389
#           2       0.47      0.59      0.52       394
#           3       0.34      0.12      0.18       251
#
# avg / total       0.44      0.46      0.44      1353
#
# 86 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.40      0.40       319
#           1       0.51      0.57      0.54       389
#           2       0.46      0.59      0.52       394
#           3       0.33      0.12      0.18       251
#
# avg / total       0.44      0.45      0.43      1353
#
# 87 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.41      0.40       319
#           1       0.52      0.58      0.55       389
#           2       0.47      0.59      0.52       394
#           3       0.34      0.13      0.19       251
#
# avg / total       0.44      0.46      0.44      1353
#
# 88 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.40      0.40       319
#           1       0.52      0.57      0.54       389
#           2       0.46      0.58      0.51       394
#           3       0.34      0.13      0.19       251
#
# avg / total       0.44      0.45      0.43      1353
#
# 89 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.41      0.40       319
#           1       0.52      0.56      0.54       389
#           2       0.46      0.58      0.51       394
#           3       0.36      0.13      0.19       251
#
# avg / total       0.44      0.45      0.43      1353
#
# 90 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.41      0.40       319
#           1       0.52      0.56      0.54       389
#           2       0.46      0.59      0.52       394
#           3       0.36      0.14      0.20       251
#
# avg / total       0.44      0.46      0.44      1353
#
# 91 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.40      0.40       319
#           1       0.52      0.55      0.53       389
#           2       0.46      0.59      0.52       394
#           3       0.38      0.14      0.20       251
#
# avg / total       0.44      0.45      0.43      1353
#
# 92 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.42      0.41       319
#           1       0.51      0.55      0.53       389
#           2       0.46      0.59      0.52       394
#           3       0.38      0.14      0.20       251
#
# avg / total       0.45      0.45      0.44      1353
#
# 93 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.42      0.41       319
#           1       0.52      0.55      0.53       389
#           2       0.46      0.59      0.52       394
#           3       0.37      0.14      0.20       251
#
# avg / total       0.44      0.45      0.44      1353
#
# 94 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.43      0.41       319
#           1       0.52      0.55      0.53       389
#           2       0.46      0.59      0.52       394
#           3       0.37      0.13      0.19       251
#
# avg / total       0.45      0.46      0.44      1353
#
# 95 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.44      0.42       319
#           1       0.52      0.55      0.53       389
#           2       0.46      0.58      0.51       394
#           3       0.39      0.14      0.20       251
#
# avg / total       0.45      0.46      0.44      1353
#
# 96 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.42      0.41       319
#           1       0.52      0.56      0.54       389
#           2       0.46      0.59      0.51       394
#           3       0.38      0.13      0.19       251
#
# avg / total       0.45      0.46      0.44      1353
#
# 97 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.44      0.42       319
#           1       0.52      0.55      0.54       389
#           2       0.46      0.58      0.51       394
#           3       0.38      0.14      0.20       251
#
# avg / total       0.45      0.46      0.44      1353
#
# 98 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.43      0.41       319
#           1       0.51      0.56      0.53       389
#           2       0.45      0.57      0.50       394
#           3       0.39      0.14      0.21       251
#
# avg / total       0.45      0.45      0.44      1353
#
# 99 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.41      0.44      0.42       319
#           1       0.52      0.57      0.54       389
#           2       0.46      0.57      0.51       394
#           3       0.40      0.14      0.20       251
#
# avg / total       0.45      0.46      0.44      1353
#
# 100 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.44      0.42       319
#           1       0.51      0.57      0.53       389
#           2       0.46      0.57      0.51       394
#           3       0.40      0.14      0.20       251
#
# avg / total       0.45      0.46      0.44      1353
#
# 101 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.38      0.40      0.39       319
#           1       0.51      0.56      0.53       389
#           2       0.46      0.57      0.51       394
#           3       0.42      0.15      0.22       251
#
# avg / total       0.45      0.45      0.44      1353
#
# 102 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.38      0.41      0.39       319
#           1       0.50      0.56      0.53       389
#           2       0.45      0.57      0.50       394
#           3       0.39      0.13      0.20       251
#
# avg / total       0.44      0.45      0.43      1353
#
# 103 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.37      0.40      0.39       319
#           1       0.51      0.56      0.53       389
#           2       0.45      0.56      0.50       394
#           3       0.37      0.14      0.20       251
#
# avg / total       0.43      0.44      0.43      1353
#
# 104 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.38      0.41      0.40       319
#           1       0.51      0.56      0.53       389
#           2       0.45      0.57      0.51       394
#           3       0.40      0.14      0.20       251
#
# avg / total       0.44      0.45      0.43      1353
#
# 105 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.38      0.41      0.39       319
#           1       0.50      0.55      0.53       389
#           2       0.45      0.56      0.50       394
#           3       0.40      0.14      0.21       251
#
# avg / total       0.44      0.44      0.43      1353
#
# 106 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.42      0.40       319
#           1       0.51      0.56      0.53       389
#           2       0.45      0.56      0.50       394
#           3       0.41      0.15      0.22       251
#
# avg / total       0.44      0.45      0.43      1353
#
# 107 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.38      0.41      0.39       319
#           1       0.50      0.56      0.53       389
#           2       0.46      0.55      0.50       394
#           3       0.40      0.15      0.22       251
#
# avg / total       0.44      0.45      0.43      1353
#
# 108 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.40      0.42      0.41       319
#           1       0.50      0.56      0.53       389
#           2       0.45      0.56      0.50       394
#           3       0.41      0.16      0.23       251
#
# avg / total       0.45      0.45      0.44      1353
#
# 109 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.38      0.39      0.39       319
#           1       0.50      0.57      0.53       389
#           2       0.45      0.55      0.49       394
#           3       0.38      0.15      0.22       251
#
# avg / total       0.44      0.44      0.43      1353
#
# 110 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.40      0.39       319
#           1       0.50      0.56      0.53       389
#           2       0.44      0.56      0.49       394
#           3       0.39      0.14      0.21       251
#
# avg / total       0.44      0.44      0.43      1353
#
# 111 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.40      0.39       319
#           1       0.51      0.56      0.53       389
#           2       0.44      0.55      0.49       394
#           3       0.39      0.14      0.21       251
#
# avg / total       0.44      0.44      0.43      1353
#
# 112 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.40      0.40       319
#           1       0.50      0.56      0.53       389
#           2       0.44      0.55      0.49       394
#           3       0.39      0.14      0.21       251
#
# avg / total       0.44      0.44      0.43      1353
#
# 113 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.38      0.40      0.39       319
#           1       0.51      0.54      0.52       389
#           2       0.43      0.56      0.49       394
#           3       0.39      0.14      0.21       251
#
# avg / total       0.43      0.44      0.42      1353
#
# 114 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.38      0.41      0.40       319
#           1       0.50      0.54      0.52       389
#           2       0.44      0.55      0.49       394
#           3       0.37      0.14      0.20       251
#
# avg / total       0.43      0.44      0.42      1353
#
# 115 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.40      0.40       319
#           1       0.50      0.56      0.53       389
#           2       0.44      0.55      0.49       394
#           3       0.36      0.14      0.20       251
#
# avg / total       0.43      0.44      0.43      1353
#
# 116 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.40      0.40       319
#           1       0.50      0.55      0.53       389
#           2       0.44      0.55      0.49       394
#           3       0.35      0.14      0.20       251
#
# avg / total       0.43      0.44      0.42      1353
#
# 117 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.41      0.40       319
#           1       0.51      0.54      0.52       389
#           2       0.44      0.55      0.49       394
#           3       0.36      0.14      0.21       251
#
# avg / total       0.43      0.44      0.42      1353
#
# 118 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.42      0.40       319
#           1       0.50      0.53      0.51       389
#           2       0.44      0.56      0.49       394
#           3       0.37      0.14      0.20       251
#
# avg / total       0.43      0.44      0.42      1353
#
# 119 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.38      0.41      0.39       319
#           1       0.50      0.54      0.52       389
#           2       0.44      0.56      0.49       394
#           3       0.36      0.13      0.19       251
#
# avg / total       0.43      0.44      0.42      1353
#
# 120 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.37      0.39      0.38       319
#           1       0.50      0.53      0.51       389
#           2       0.43      0.55      0.49       394
#           3       0.37      0.14      0.20       251
#
# avg / total       0.43      0.43      0.42      1353
#
# 121 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.38      0.39      0.39       319
#           1       0.50      0.55      0.53       389
#           2       0.44      0.56      0.49       394
#           3       0.37      0.15      0.21       251
#
# avg / total       0.43      0.44      0.42      1353
#
# 122 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.37      0.38      0.37       319
#           1       0.50      0.54      0.52       389
#           2       0.44      0.55      0.49       394
#           3       0.36      0.15      0.21       251
#
# avg / total       0.42      0.43      0.42      1353
#
# 123 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.37      0.39      0.38       319
#           1       0.50      0.53      0.51       389
#           2       0.44      0.56      0.49       394
#           3       0.36      0.14      0.20       251
#
# avg / total       0.43      0.43      0.42      1353
#
# 124 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.36      0.38      0.37       319
#           1       0.50      0.52      0.51       389
#           2       0.43      0.56      0.49       394
#           3       0.37      0.15      0.21       251
#
# avg / total       0.42      0.43      0.41      1353
#
# 125 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.37      0.39      0.38       319
#           1       0.50      0.53      0.51       389
#           2       0.44      0.56      0.49       394
#           3       0.36      0.14      0.21       251
#
# avg / total       0.43      0.43      0.42      1353
#
# 126 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.37      0.38      0.37       319
#           1       0.50      0.53      0.52       389
#           2       0.43      0.56      0.49       394
#           3       0.38      0.16      0.22       251
#
# avg / total       0.43      0.43      0.42      1353
#
# 127 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.37      0.38      0.37       319
#           1       0.50      0.55      0.53       389
#           2       0.43      0.55      0.48       394
#           3       0.39      0.16      0.23       251
#
# avg / total       0.43      0.44      0.42      1353
#
# 128 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.40      0.40       319
#           1       0.51      0.56      0.53       389
#           2       0.44      0.55      0.49       394
#           3       0.40      0.16      0.23       251
#
# avg / total       0.44      0.45      0.43      1353
#
# 129 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.39      0.39      0.39       319
#           1       0.50      0.56      0.53       389
#           2       0.44      0.55      0.49       394
#           3       0.40      0.16      0.23       251
#
# avg / total       0.44      0.44      0.43      1353
#
# 130 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.38      0.39      0.39       319
#           1       0.49      0.56      0.52       389
#           2       0.44      0.55      0.49       394
#           3       0.41      0.16      0.23       251
#
# avg / total       0.44      0.44      0.43      1353
#
# 131 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.38      0.39      0.39       319
#           1       0.49      0.56      0.52       389
#           2       0.44      0.54      0.48       394
#           3       0.42      0.17      0.24       251
#
# avg / total       0.44      0.44      0.43      1353
#
# 132 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
# ...
#
#           0       0.32      0.24      0.27       319
#           1       0.42      0.63      0.50       389
#           2       0.43      0.46      0.45       394
#           3       0.38      0.17      0.24       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 207 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.24      0.27       319
#           1       0.42      0.62      0.50       389
#           2       0.43      0.46      0.45       394
#           3       0.37      0.17      0.23       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 208 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.31      0.24      0.27       319
#           1       0.42      0.62      0.50       389
#           2       0.43      0.47      0.45       394
#           3       0.36      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 209 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.23      0.27       319
#           1       0.42      0.63      0.50       389
#           2       0.43      0.47      0.45       394
#           3       0.35      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 210 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.23      0.27       319
#           1       0.42      0.62      0.50       389
#           2       0.43      0.47      0.45       394
#           3       0.35      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 211 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.31      0.23      0.27       319
#           1       0.42      0.63      0.50       389
#           2       0.44      0.47      0.45       394
#           3       0.37      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 212 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.33      0.24      0.28       319
#           1       0.42      0.62      0.50       389
#           2       0.44      0.48      0.46       394
#           3       0.38      0.16      0.22       251
#
# avg / total       0.39      0.41      0.38      1353
#
# 213 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.24      0.28       319
#           1       0.42      0.62      0.50       389
#           2       0.44      0.48      0.46       394
#           3       0.37      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 214 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.25      0.28       319
#           1       0.42      0.62      0.50       389
#           2       0.43      0.46      0.45       394
#           3       0.38      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 215 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.31      0.24      0.27       319
#           1       0.42      0.62      0.50       389
#           2       0.43      0.46      0.44       394
#           3       0.37      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 216 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.25      0.28       319
#           1       0.41      0.62      0.50       389
#           2       0.43      0.45      0.44       394
#           3       0.38      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 217 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.33      0.26      0.29       319
#           1       0.42      0.63      0.50       389
#           2       0.43      0.45      0.44       394
#           3       0.37      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 218 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.33      0.25      0.28       319
#           1       0.42      0.63      0.51       389
#           2       0.43      0.46      0.45       394
#           3       0.37      0.16      0.23       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 219 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.24      0.27       319
#           1       0.42      0.62      0.50       389
#           2       0.42      0.46      0.44       394
#           3       0.37      0.16      0.23       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 220 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.24      0.28       319
#           1       0.42      0.62      0.50       389
#           2       0.43      0.46      0.44       394
#           3       0.39      0.18      0.25       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 221 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.33      0.24      0.28       319
#           1       0.42      0.61      0.50       389
#           2       0.43      0.46      0.44       394
#           3       0.37      0.17      0.23       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 222 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.33      0.24      0.28       319
#           1       0.42      0.62      0.50       389
#           2       0.43      0.46      0.45       394
#           3       0.36      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 223 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.33      0.24      0.28       319
#           1       0.42      0.62      0.50       389
#           2       0.43      0.46      0.45       394
#           3       0.37      0.17      0.23       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 224 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.24      0.27       319
#           1       0.42      0.62      0.50       389
#           2       0.44      0.46      0.45       394
#           3       0.37      0.19      0.25       251
#
# avg / total       0.39      0.41      0.39      1353
#
# 225 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.33      0.24      0.28       319
#           1       0.42      0.62      0.50       389
#           2       0.44      0.46      0.45       394
#           3       0.37      0.18      0.24       251
#
# avg / total       0.39      0.40      0.39      1353
#
# 226 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.24      0.27       319
#           1       0.42      0.62      0.50       389
#           2       0.43      0.46      0.45       394
#           3       0.36      0.18      0.24       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 227 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.31      0.23      0.26       319
#           1       0.42      0.62      0.50       389
#           2       0.43      0.46      0.44       394
#           3       0.37      0.18      0.24       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 228 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.31      0.23      0.26       319
#           1       0.42      0.62      0.50       389
#           2       0.43      0.46      0.45       394
#           3       0.37      0.18      0.24       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 229 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.31      0.23      0.26       319
#           1       0.42      0.62      0.50       389
#           2       0.43      0.46      0.45       394
#           3       0.37      0.18      0.24       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 230 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.31      0.23      0.26       319
#           1       0.42      0.62      0.50       389
#           2       0.44      0.46      0.45       394
#           3       0.37      0.18      0.24       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 231 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.24      0.27       319
#           1       0.43      0.62      0.50       389
#           2       0.44      0.47      0.46       394
#           3       0.36      0.18      0.24       251
#
# avg / total       0.39      0.41      0.39      1353
#
# 232 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.24      0.27       319
#           1       0.42      0.61      0.50       389
#           2       0.44      0.47      0.46       394
#           3       0.35      0.18      0.24       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 233 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.33      0.25      0.29       319
#           1       0.42      0.62      0.50       389
#           2       0.43      0.47      0.45       394
#           3       0.37      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 234 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.31      0.24      0.27       319
#           1       0.42      0.61      0.50       389
#           2       0.43      0.47      0.45       394
#           3       0.38      0.16      0.23       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 235 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.31      0.24      0.27       319
#           1       0.42      0.61      0.50       389
#           2       0.43      0.47      0.45       394
#           3       0.39      0.17      0.23       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 236 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.31      0.24      0.27       319
#           1       0.43      0.62      0.51       389
#           2       0.44      0.48      0.46       394
#           3       0.38      0.17      0.23       251
#
# avg / total       0.40      0.41      0.39      1353
#
# 237 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.31      0.24      0.28       319
#           1       0.43      0.62      0.51       389
#           2       0.44      0.48      0.46       394
#           3       0.39      0.17      0.23       251
#
# avg / total       0.40      0.41      0.39      1353
#
# 238 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.25      0.28       319
#           1       0.43      0.61      0.50       389
#           2       0.44      0.48      0.46       394
#           3       0.38      0.16      0.23       251
#
# avg / total       0.39      0.41      0.39      1353
#
# 239 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.25      0.28       319
#           1       0.42      0.62      0.50       389
#           2       0.44      0.48      0.46       394
#           3       0.37      0.16      0.23       251
#
# avg / total       0.39      0.41      0.39      1353
#
# 240 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.25      0.28       319
#           1       0.42      0.60      0.49       389
#           2       0.44      0.48      0.46       394
#           3       0.38      0.17      0.23       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 241 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.25      0.28       319
#           1       0.42      0.61      0.49       389
#           2       0.44      0.48      0.46       394
#           3       0.39      0.17      0.24       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 242 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.33      0.25      0.28       319
#           1       0.42      0.61      0.49       389
#           2       0.44      0.48      0.46       394
#           3       0.39      0.17      0.24       251
#
# avg / total       0.40      0.40      0.39      1353
#
# 243 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.25      0.28       319
#           1       0.42      0.61      0.49       389
#           2       0.44      0.48      0.46       394
#           3       0.38      0.18      0.24       251
#
# avg / total       0.40      0.40      0.39      1353
#
# 244 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.25      0.28       319
#           1       0.42      0.60      0.49       389
#           2       0.44      0.48      0.46       394
#           3       0.37      0.17      0.23       251
#
# avg / total       0.39      0.40      0.39      1353
#
# 245 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.24      0.27       319
#           1       0.42      0.62      0.50       389
#           2       0.43      0.47      0.45       394
#           3       0.35      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 246 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.24      0.27       319
#           1       0.42      0.62      0.50       389
#           2       0.44      0.48      0.46       394
#           3       0.36      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 247 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.24      0.27       319
#           1       0.42      0.61      0.50       389
#           2       0.44      0.48      0.46       394
#           3       0.36      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 248 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.24      0.27       319
#           1       0.42      0.61      0.49       389
#           2       0.43      0.48      0.46       394
#           3       0.36      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 249 passes : Doc2Vec(dbow,d100,n5,mc2,t8)
#              precision    recall  f1-score   support
#
#           0       0.32      0.24      0.27       319
#           1       0.42      0.61      0.50       389
#           2       0.43      0.48      0.46       394
#           3       0.36      0.16      0.22       251
#
# avg / total       0.39      0.40      0.38      1353
#
# 250 passes : Doc2Vec(dbow,d100,n5,mc2,t8)

# %%
from random import shuffle
import datetime

alpha, min_alpha, passes = (0.025, 0.001, 5)
alpha_delta = (alpha - min_alpha) / passes

print("START %s" % datetime.datetime.now())

for epoch in range(passes):
    shuffle(doc_list)  # shuffling gets best results
    
    for name, train_model in models_by_name.items():
        # train
        duration = 'na'
        train_model.alpha, train_model.min_alpha = alpha, alpha
        with elapsed_timer() as elapsed:
            train_model.train(doc_list)
            duration = '%.1f' % elapsed()
            
        # evaluate
        eval_duration = ''
        with elapsed_timer() as eval_elapsed:
            err, err_count, test_count, predictor = error_rate_for_model(train_model, train_docs, test_docs)
        eval_duration = '%.1f' % eval_elapsed()
        best_indicator = ' '
        if err <= best_error[name]:
            best_error[name] = err
            best_indicator = '*' 
        print("%s%f : %i passes : %s %ss %ss" % (best_indicator, err, epoch + 1, name, duration, eval_duration))

        if ((epoch + 1) % 5) == 0 or epoch == 0:
            eval_duration = ''
            with elapsed_timer() as eval_elapsed:
                infer_err, err_count, test_count, predictor = error_rate_for_model(train_model, train_docs, test_docs, infer=True)
            eval_duration = '%.1f' % eval_elapsed()
            best_indicator = ' '
            if infer_err < best_error[name + '_inferred']:
                best_error[name + '_inferred'] = infer_err
                best_indicator = '*'
            print("%s%f : %i passes : %s %ss %ss" % (best_indicator, infer_err, epoch + 1, name + '_inferred', duration, eval_duration))

    print('completed pass %i at alpha %f' % (epoch + 1, alpha))
    alpha -= alpha_delta
    
print("END %s" % str(datetime.datetime.now()))
# Out:
# START 2015-07-16 06:00:42.449288
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-b190ec7c65c5> in <module>()
#      21         eval_duration = ''
#      22         with elapsed_timer() as eval_elapsed:
# ---> 23             err, err_count, test_count, predictor = error_rate_for_model(train_model, train_docs, test_docs)
#      24         eval_duration = '%.1f' % eval_elapsed()
#      25         best_indicator = ' '
#
# <ipython-input-14-18d9abcd38d1> in error_rate_for_model(test_model, train_set, test_set, infer, infer_steps, infer_alpha, infer_subsample)
#      28     #print train_regressors
#      29     #train_regressors = sm.add_constant(train_regressors)
# ---> 30     predictor = logistic_predictor_from_data(train_targets, train_regressors)
#      31
#      32     test_data = test_set
#
# <ipython-input-14-18d9abcd38d1> in logistic_predictor_from_data(train_targets, train_regressors)
#      17
#      18 def logistic_predictor_from_data(train_targets, train_regressors):
# ---> 19     logit = sm.Logit(train_targets, train_regressors)
#      20     predictor = logit.fit(disp=0)
#      21     #print(predictor.summary())
#
# /home/skillachie/Development/lang/pyenv/local/lib/python2.7/site-packages/statsmodels/discrete/discrete_model.pyc in __init__(self, endog, exog, **kwargs)
#     402         if (self.__class__.__name__ != 'MNLogit' and
#     403                 not np.all((self.endog >= 0) & (self.endog <= 1))):
# --> 404             raise ValueError("endog must be in the unit interval.")
#     405
#     406
#
# ValueError: endog must be in the unit interval.
